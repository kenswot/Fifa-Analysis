# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data = pd.read_csv('data.csv')
print(data.shape)
# Out:
# (18207, 89)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %%
def club(y):
    return data[data['Club'] == y][['Name', 'Overall',  'Position', 'Nationality', 'BallControl', 'Special' , 'Weak Foot', 'Work Rate', 'Joined',  'International Reputation']]
club('Arsenal')
# Out:
#                     Name  Overall Position         Nationality  BallControl  \
# 33         P. Aubameyang       88       LM               Gabon         82.0
# 74               M. Özil       86      CAM             Germany         90.0
# 87          A. Lacazette       85       ST              France         83.0
# 131              B. Leno       84       GK             Germany         22.0
# 146             Sokratis       84      RCB              Greece         58.0
# 199        H. Mkhitaryan       83       RM             Armenia         86.0
# 235          L. Torreira       82      LCM             Uruguay         81.0
# 281           S. Mustafi       82      RCB             Germany         70.0
# 289            A. Ramsey       82      CAM               Wales         82.0
# 311         L. Koscielny       82       CB              France         66.0
# 317              P. Čech       82       GK      Czech Republic         22.0
# ...

# %%
def country(x):
    return data[data['Nationality'] == x][['Name', 'Overall', 'Potential', 'Position', 'Club' , 'International Reputation']]

country('Nigeria').head(40)
# Out:
#                    Name  Overall  Potential Position  \
# 425            W. Ndidi       80         85      LDM
# 789            A. Iwobi       78         84       LM
# 858            V. Moses       78         78       RW
# 1022          O. Ighalo       77         77       ST
# 1296        H. Onyekuru       76         86       ST
# 1531            A. Umar       76         81       RM
# 1550           M. Simon       76         82       LM
# 1615         L. Balogun       75         75       CB
# 1701             M. Agu       75         80      RDM
# 1754            A. Musa       75         77       LM
# 1942           O. Onazi       75         78      RDM
# 1946       K. Iheanacho       75         83       ST
# 2179             J. Obi       74         75      LCM
# 2282          O. Kayode       74         78       ST
# 2382            S. Kalu       74         85       RW
# 2431          E. Dennis       74         85       RM
# 2535           O. Etebo       74         84      RCM
# ...

# %%
                     
def club(x):
    return data[data['Club'] == x ][['Name', 'Jersey Number','Position', 'Overall', 'Nationality', 'Age', 'Wage', 'Value', 'Contract Valid Until',  'International Reputation']]

club('FC Barcelona').head(20)
                     
# def country(x):
#     return data[data['Nationality'] == x][['Name', 'Overall', 'Potential', 'Position', 'Club', 'Rating']]

# country('Nigeria').head(40)
# Out:
#                  Name  Jersey Number Position  Overall  Nationality  Age  \
# 0            L. Messi           10.0       RF       94    Argentina   31
# 7           L. Suárez            9.0       RS       91      Uruguay   31
# 18      M. ter Stegen           22.0       GK       89      Germany   26
# 20    Sergio Busquets            5.0      CDM       89        Spain   29
# 32           Coutinho            7.0       LW       88       Brazil   26
# 42          S. Umtiti           23.0       CB       87       France   24
# 49         Jordi Alba           18.0       LB       87        Spain   29
# 53         I. Rakitić            4.0      RCM       87      Croatia   30
# 54              Piqué            3.0      RCB       87        Spain   31
# 96           A. Vidal            8.0      CAM       85        Chile   31
# 155        O. Dembélé           11.0       RW       83       France   21
# 192     Sergi Roberto           20.0       RB       83        Spain   26
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
data["Wage"].plot();

# %%
# Filling the missing data
data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace = True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace = True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
data['FKAccuracy'].fillna(data['FKAccuracy'], inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
data['Jersey Number'].fillna(8, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Meduim/ Meduim', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna( 1, inplace = True)
data['Wage'].fillna('$200k', inplace = True)
data.fillna(0, inplace = True)

# %%
def defending(data):
    return int(round((data[['Marking', 'StandingTackle', 'SlidingTackle']].mean()).mean()))
def general(data):
    return int(round((data[['HeadingAccuracy', 'Dribbling', 'Curve', 'BallControl']].mean()).mean()))
def mental(data):
    return int(round((data[['Agression', 'Interceptions', 'Positioning', 'Composure']].mean()).mean()))
def passing(data):
    return int(round((data[['Crossing', 'ShortPassing', 'LongPassing']].mean()).mean()))
def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed', 'Agility', 'Reactions']].mean()).mean()))
def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina', 'Strength']].mean()).mean()))
def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean()))
def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy']].mean()).mean()))

# %%
data.rename(columns={'Club Logo': 'Club_Logo'}, inplace = True)
# Renaming the columns

data['Defending'] = data.apply(defending, axis = 1)
data['General'] = data.apply(general, axis = 1)
data['Mental'] = data.apply(mental, axis = 1)
data['Passing'] = data.apply(passing, axis = 1)
data['Mobility'] = data.apply(mobility, axis = 1)
data['Rating'] = data.apply(rating, axis = 1)
data['Shooting'] = data.apply(shooting, axis = 1)
data['Power'] = data.apply(power, axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:1152: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]

# %%
players = data[['Name', 'Defending', 'General', 'Mental', 'Passing',
               'Mobility', 'Power', 'Rating', 'Shooting', 'Flag', 'Age',
               'Nationality', 'Photo', 'Club_Logo', 'Club']]

# %%
data['Preferred Foot']
# Out:
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18207, dtype: object

# %%
from cycler import cycler
import matplotlib as mpl
plt.style.use('ggplot')
data = np.random.randn(50)

print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(data['Preferred Foot'], palette = 'pink')
plt.title('Most Preferred Foot of the  Player', fontsize = 20)
plt.show()

# %%
labels = ['1', '2', '3', '4', '5']
sizes = data['International Reputation'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0.1, 0.1, 0.2, 0.5, 0.9]

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True)
plt.title('International Reputation', fontsize = 20)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (18, 8))
plt.style.use('fivethirtyeight')
ax = sns.countplot('Position', data = data, palette = 'bone')
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize= 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 16)
ax.set_title(label = 'Comparison of Positions and Players', fontsize = 20)
plt.show()

# %%
# Defining a function for cleaning the weight data

def extract_value_from(value):
    out = value.replace('lbs', '')
    return float(out)
#applying the function to weight column
#data['value'] = data['value'].apply(lamba x: extract_value_from(x))

data['weight'] = data['Weight'].apply(lambda x : extract_value_from(x))

data['Weight'].head()
# Out:
# 0    159lbs
# 1    183lbs
# 2    150lbs
# 3    168lbs
# 4    154lbs
# Name: Weight, dtype: object

# %% [markdown]
# ## Defining a function for cleaning the wage column

# %%
def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1000
    return float(out)

# %%
data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))

data['Wage'].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %% [markdown]
# ## Comparing the players wages

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (15, 5)
sns.countplot(data['Wage'].iloc[1:100], color = 'blue')
plt.xlabel('Wage Range for Players', fontsize = 16)
plt.ylabel('COunt of the Players', fontsize = 16)
plt.title('Distribution of Wages of the Players', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Skills move of Players

# %%
plt.figure(figsize = (10, 8))
ax = sns.countplot(x = 'Skill Moves', data = data, palette = 'pastel')
ax.set_title(label = 'Count of players on Basis of their skill moves', fontsize = 20)
ax.set_xlabel(xlabel = 'Number of Skill Moves', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %% [markdown]
# ## Height of the players

# %%
plt.figure(figsize = (13, 8))
ax = sns.countplot(x = 'Height', data = data, palette = 'dark')
ax.set_title(label = 'Count of players on Basis of Height', fontsize = 20)
ax.set_xlabel(xlabel = 'Height in Foot per inch', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %% [markdown]
# ## Show differnet body weight of the players participating in FiFa 2019

# %%
data['Weight']
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
plt.figure(figsize = (20, 5))
sns.countplot(data['Weight'].iloc[1:80])
plt.title('Different Weight of the Players Participating in FIFA 2019', fontsize = 20)
plt.xlabel('Height associated with players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()

# %% [markdown]
# ## Showing workrate

# %%
plt.figure(figsize = (15, 7))

sns.countplot(data ['Work Rate'], palette = 'hls')
plt.title('Different work rates of the Players Participating in FIFA 2019', fontsize = 20)
plt.xlabel('Work rates associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()

# %% [markdown]
# ## Show a different speciality score of players participating in Fifa 2019

# %%
x = data.Special
plt.figure(figsize = (12, 8))
plt.style.use('tableau-colorblind10')

ax = sns.distplot(x, bins = 58, kde = False, color = 'm')
ax.set_xlabel(xlabel = 'Special score range', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of the Players', fontsize = 16)
ax.set_title(label = 'Histogram for Speciality Scores of the Players', fontsize = 20)
plt.show()

# %% [markdown]
# ## Showing differnet nations participating in FIFA 2019

# %%
plt.style.use('dark_background')
data['Nationality'].value_counts().head(80).plot.bar(color = 'orange', figsize = (20, 7))
plt.title('Different Nations Participating in FIFA 2019', fontsize = 30, fontweight = 20)
plt.xlabel('Name of The Country')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## most players by Country

# %%
data['Nationality'].value_counts().head(10)
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %% [markdown]
# ## Most popular clubs

# %%
data['Club'].value_counts().head(20)
# Out:
# No Club                    241
# Chelsea                     33
# Atlético Madrid             33
# Borussia Dortmund           33
# Manchester City             33
# Burnley                     33
# Wolverhampton Wanderers     33
# Southampton                 33
# Valencia CF                 33
# Newcastle United            33
# Liverpool                   33
# Cardiff City                33
# Everton                     33
# RC Celta                    33
# Fortuna Düsseldorf          33
# TSG 1899 Hoffenheim         33
# Rayo Vallecano              33
# Arsenal                     33
# Frosinone                   33
# Eintracht Frankfurt         33
# Name: Club, dtype: int64

# %%
data['Overall']
# Out:
# 0        94
# 1        94
# 2        92
# 3        91
# 4        91
#          ..
# 18202    47
# 18203    47
# 18204    47
# 18205    47
# 18206    46
# Name: Overall, Length: 18207, dtype: int64

# %%
some_clubs = ('Manchester City', 'Manchester United', 'Arsenal', 'Chelsea', 'FC Barcelona', 'Liverpool', )
data_clubs = data.loc[data['Club'].isin(some_clubs) & data['Overall']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.boxplot      (x = data_clubs['Club'], y = data_clubs['Overall'], palette = 'inferno')
ax.set_xlabel(xlabel = 'Some Popular Clubs', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Score', fontsize = 9)
ax.set_title(label = 'Distribution of Overall Score in Different Popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
data['Club']
# Out:
# 0               FC Barcelona
# 1                   Juventus
# 2        Paris Saint-Germain
# 3          Manchester United
# 4            Manchester City
#                 ...
# 18202        Crewe Alexandra
# 18203         Trelleborgs FF
# 18204       Cambridge United
# 18205        Tranmere Rovers
# 18206        Tranmere Rovers
# Name: Club, Length: 18207, dtype: object

# %%
plt.figure(figsize = (15, 7))

sns.countplot(data ['Overall'], palette = 'hls')
plt.title('Different work rates of the Players Participating in FIFA 2019', fontsize = 20)
plt.xlabel('Work rates associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()

# %%
df.plot[x = '', y = ["Name", "Club", "Overall"], kind="bar"]
# Out:
#   File "<ipython-input-118-ea1d97dfb993>", line 1
#     df.plot[x = '', y = ["Name", "Club", "Overall"], kind="bar"]
#               ^
# SyntaxError: invalid syntax

# %%
data[:-9].plot(x='Name', y=['Overall'],color= 'orange', figsize=(15, 5), grid=True)
plt.title('Worst Players in the World', fontsize = 20)
plt.xlabel('Name Of the Players', fontsize = 16)
plt.ylabel('Rating', fontsize = 16);

# %%
def toy(x):
    return data[data['Name'] == x][['Name', 'Overall',  'Position', 'Nationality','Age', 'BallControl', 'Special' , 'Weak Foot', 'Work Rate', 'Joined',  'International Reputation']]

toy('J. Haugaard')
# Out:
#               Name  Overall Position Nationality  Age  BallControl  Special  \
# 10000  J. Haugaard       65       GK     Denmark   26         20.0     1071
#
#        Weak Foot       Work Rate        Joined  International Reputation
# 10000        3.0  Medium/ Medium  Jun 15, 2015                       1.0

# %%
data[:10].plot(x='Name', y=['Overall'],color= 'orange', figsize=(15, 5), grid=True)
plt.title('Best Players in the World', fontsize = 20)
plt.xlabel('Name Of the Players', fontsize = 16)
plt.ylabel('Rating', fontsize = 16);

# %%
data['Age'].min()
# Out:
# 16

# %% [markdown]
# ## Data science life cycle includes all the processes involved in any Data Science projects
#
# 1. Data Acquisition
# 2. Data Processing
# 3. Data Exploration
# 4. Modelling
# 5.

# %%
plt.style.use('dark_background')
data['Release Clause'].value_counts().head(80).plot.bar(color = 'orange', figsize = (20, 7))
plt.title('Different Nations Participating in FIFA 2019', fontsize = 30, fontweight = 20)
plt.xlabel('Name of The Country')
plt.ylabel('Count')
plt.show()

# %%
data['Release Clause'].max
# Out:
# <bound method Series.max of 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
#           ...
# 18202      €143K
# 18203      €113K
# 18204      €165K
# 18205      €143K
# 18206      €165K
# Name: Release Clause, Length: 18207, dtype: object>

# %%
data['Release Clause'].isnull().values.any()
# Out:
# True

# %%
data['Release Clause'] = data['Release Clause'].fillna(0)

# %%
data['Release  Clause'] = data['Release Clause'].replace('\D', '', regex = True).astype(int)

# %%
data['Release Clause']
# Out:
# 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
#           ...
# 18202      €143K
# 18203      €113K
# 18204      €165K
# 18205      €143K
# 18206      €165K
# Name: Release Clause, Length: 18207, dtype: object

# %%
data.hist(figsize = (20, 20))
plt.show()

# %%
def toy(x):
    return data[data['Name'] == x][[ 'Overall', 'Potential', 'Position', 'Club' , 'International Reputation']]

toy('P. Aubameyang')
# Out:
#     Overall  Potential Position     Club  International Reputation
# 33       88         88       LM  Arsenal                       3.0
